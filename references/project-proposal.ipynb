# %% [markdown]
# # Project proposal
#
# ---
#
# Group name: DA-Statistics-Nadine-Alena
#
# ---

# %% [markdown]
# ## Introduction
#
# The introduction section includes
#
# -   an introduction to the subject matter you're investigating
# -   the motivation for your research question (citing any relevant literature)
# -   the general research question you wish to explore
# -   your hypotheses regarding the research question of interest.
#
# In der heutigen Zeit spielt die Digitalisierung nicht nur im beruflichen Umfeld eine Rolle. Auch im privaten Umfeld ist diese nicht mehr weg zu denken. Sie hat die Art und Weise wie Menschen miteinander agieren beeinflusst. Längst unterstützt die Digitalisierung auch bei der Partnersuche. Es gibt zahlreiche Online-Partnervermittlungen und Singlebörsen wie beispielsweise Parship und ElitePartner. Am beliebsten sind allerdings die Dating Apps wie Tinder, Bumble oder Lovoo. 65% der Nutzerinnen und Nutzer von Online-Dating waren auf einer Dating App schon einmal aktiv. (Quelle: https://www.bitkom.org/Presse/Presseinformation/Online-Dating-Haelfte-sucht-langfristige-Partnerschaft)
# Dabei geht suchen viele der Nutzerinnen und Nutzer nicht nur nach einem unverbindlichen Flirt, denn einer neuen Studie zufolge sucht immerhin mehr als die Hälfte nach einem Partner oder einer Partnerin für eine langfristige Beziehung. (Quelle: https://www.bitkom.org/Presse/Presseinformation/Online-Dating-Haelfte-sucht-langfristige-Partnerschaft)
#
# Gerade bei den Dating Plattformen ist der erste Eindruck entscheidet. Ein Blick auf das Profilbild oder das Nutzerprofil muss ausreichen um sich für oder gegen die Kontaktaufnahme zu entscheiden. Umso wichtiger ist es, dass man mit diesen Angaben das Interesse der anderen NUtzerinnen und Nutzer erweckt. Die Mehrheit der Frauen und Männer glauben nämlich, dass hinter einem spärlich befüllten Profil ein ersnthaftes Interesse steckt. (Quelle: https://www.parship.de/studien/parship-wissen-vorurteile-bei-der-partnersuche-wie-sehr-lassen-wir-uns-von-profilbild-koerpergroesse-beruf-und-co-beeinflussen/) Doch welche Angaben wecken das Interesse der Nutzerinnen und Nutzer und erhöhen damit dei Chance auf Erfolg bei der Partnersuche.
#
# Dieses Projekt widmet sich der Analyse von Nutzerdaten, die von der Lovoo-Plattform gesammelt wurden, um ein tieferes Verständnis für das Nutzerverhalten, Präferenzen und mögliche Muster in der erfolgreichen Nutzung dieser Plattform zu gewinnen.
#
# Der vorliegende Datensatz bietet eine Fülle von Informationen über eine Vielzahl von Benutzern, darunter demografische Daten oder Aktivitätsmuster. Ziel dieses Projekts ist es, durch statistische Analysen und Datenvisualisierungen wertvolle Einblicke in verschiedene Aspekte des Nutzerverhaltens auf Lovoo zu gewinnen.
#
# Durch die Anwendung statistischer Methoden wie deskriptive Analysen, Korrelationsuntersuchungen und möglicherweise auch Vorhersagemodelle, streben wir an, Muster zu identifizieren, Trends zu erkennen und potenziell Einblicke in die Mechanismen hinter der Nutzung von Lovoo zu erhalten. Die Ergebnisse dieser Untersuchung könnten nicht nur für die Plattform selbst, sondern auch für ein breiteres Verständnis der sozialen Interaktionen in der digitalen Landschaft von Interesse sein.
#
#  Die Erkenntnisse, die aus dieser Analyse gewonnen werden, können möglichwerweise dazu beitragen Einblicke in die Verhaltensweisen und Präferenzen von Nutzern auf ähnlichen Plattformen zu liefern.

# %% [markdown]
# ## Data description
#
# In this section, you will describe the data set you wish to explore. This includes
#
# -   description of the observations in the data set,
# -   description of how the data was originally collected (not how you found the data but how the original curator of the data collected it).
#
# Grundsätzlich handelt es sich bei dem Data Set um eine Aufstellung von Informationen zu verschiedenen Nutzerprofilen auf der Dating Plattform Lovoo. Dabei repräsentiert jede Zeile, alse jeder Case, ein eigenes Nutzerprofil.
#
# #### Observations im Data Set
#
# - gender: Das Geschlecht kann grundsätzlich die Ausprägungen "F" für Female, "M" für Male oder "U" für Undefinded annehmen. Dabei bezieht sich das Geschlecht auf die Person, die das Profil erstellt hat und durch dieses repräsentiert wird.
#
# - genderLooking: Das Geschlecht, nach dem gesucht wird, kann grundsätzlich die gleichen Ausprägungen annehmen, wie beim Profilinhaber. Hierbei bezieht sich die Angabe jedoch auf den potetiellen Partner und drückt damit die sexuelle Orientierung des  Users wieder. Theoretisch ist es bei Dating Apps auch möglich anzugeben, dass das Geschlecht eines Partners keine Rolle spielt. Die Angabe, die bei "genderLooking" gemacht wird, bestimmt, welche Personengruppen dem Nutzer angezeigt werden. Der Generator des ursprünglichen Datensatzes hat so beispielsweise angegeben, dass er nach Frauen sucht, weshalb ihm auf seinem Profil lediglich Frauen angezeigt wurden.
#
# - age: In dieser Spalte wird das Alter des Profilinhabers angegeben. Das ermöglicht eine konkrete Suche nach Personen im gleichen Alter oder nach anderen präferierten Altersgruppen.
#
# - name: Die Spalte "Name" ist hier als Nutzername zu verstehen. Der hier gewählte Ausdruck kann also z.B. nur der Vorname einer Persön sein, aber auch der Spitzname oder ein frei gewählter Begriff. Er wird potenziellen Matches in der App angezeigt.
#
# - counts_details:
# - counts_pictures: Diese Spalte gibt die Anzahl der Bilder an, die auf dem Account hochgeladen wurden. Mit hochgeladenen Bildern bekommt der Gegenüber eine Vorstellung vom Aussehen der potenziellen Matches und kann so auf sehr oberflächlicher Ebene mögliche Datingpartner selektieren.
#
# - counts_profileVisits: Profile Visits auf der Dating-Plattform LOVOO bezeichnen die Anzahl der Besuche, die das eigene Benutzerprofil von anderen Nutzern erhalten hat. Wenn jemand das eigene Profil aufruft, wird dies als "Profile Visit" gezählt. Dies gibt dem Benutzer Einblick darüber, wie viele andere Mitglieder Interesse an seinem Profil zeigen, indem sie es besuchen. Profile Visits können in Dating-Apps wie LOVOO dazu beitragen, die allgemeine Aktivität und Attraktivität des eigenen Profils zu bewerten.
#
# - counts_kisses: "Kisses" sind Ausruck von Aufmerksamkeit auf der Plattform, die User verwenden können, um gegenüber anderen Nutzern ihr Interesse auszudrücken. Die virtuellen Küsse bieten Möglichkeit, jemandem zu signalisieren, das Interesse an einem Kontaktaufbau besteht oder denjenigen auf das eigene Profil zu locken. In der Regel können Kisses gekauft oder durch bestimmte Aktionen auf der Plattform verdient werden.
#
# - counts_fans: Fan auf Lovoo wird man, indem man das Profil eines anderen Nutzers marierkt und diesem folgt. Ähnlich wie bei anderen Social Media Kanälen wie z.B. Instagram, wird man dann über neue Beiträge eines Profils auf dem laufenden Gehalten und verliert dieses nicht aus den Augen.
#
# - counts_g:
# - flirtInterests_chat: Bei der Erstellung eines Profils auf LOVOO kann angegeben werden, was man auf der Plattform sucht, bzw. an welcher Art der Interaktion man interessiert ist. hierbei gibt es die Ausprägungen Chat, Freundschaften und Date. Ist im Data Set "true" bei "flitInterests_chat" angegeben, bedeutet das, dass der Profilinhaber an Onlineunterhaltungen mit anderen Nutzern interessiert ist, aber nicht zwingend mit dem Ziel dabei Freundschaften oder Partnerschaften aufzubauen.
#
# - flirtInterests_friends: Ist im Data Set "true" bei "flitInterests_friends" angegeben, ist der Profilinhaber auf der Suche nach neuen Freunden. hierdurch wird signalisiert, dass User gerne tiefere Verbindungen zu Gleichgesinnten aufbauen möchte, aber nicht unbedingt darauf abzielen, einen Partner über die Plattform zu finden.
#
# - flirtInterests_date: Ist im Data Set "true" bei "flitInterests_date" angegeben, ist der Nutzer auf der Suche nach Interaktion, die einfache Freundschaft übersteigt. Durch die Vergabe dieses Merkmals, signalisiert der User, dass er auf der Suche nach einer Liebesbeziehung ist und potenzielle Partner für Dates kontaktieren möchte.
#
# - country: "Country" gibt das Land zurück, in dem der Profilinhaber lebt. Im vorliegenden Data Set ist das z.B. SChweiz, Deutschland oder Frankreich. Die verschiedenen Länder sind mit ihren jedweiligen Länderkürzeln eingetragen, für die genannten Beispiele also "CH", "DE", "FR".
#
# - city: Ähnlich wie bei der Variablen "Country" wird hier der Wohnort des Users angegeben, diesmal in Form der Stadt, in der der Nutzer lebt. Dadurch wird die Suche nach potenziellen Partnern in der Nähe erleichtert, da dann davon ausgegangen werden kann, dass potenzielle Matches nicht nur zu Besuch in der eigenen Stadt sind, sondern auch längerfristig dort wohnen.
#
# - location: Im Gegensatz zu den beiden vorherigen Standortangaben, gibt die Variable "Location" an, wo sich der Nutzer derzeit befindet, und zwar unabhängig davon, ob der aktuelle Standort auch mit dem Wohnort übereinstimmt. Diese Angabe ist besonders dann relevant, wenn man z.B. im Urlaub neue Kontakte sucht, oder nur zeitweise den Wohnort wechselt. Häufig stimmen Location und City aber überein, immerhin halten sich viele Menschen häufig im Umkreis ihrer Wohnungen auf.
#
# - distance: In dieser Spalte wird die Entfernung zum Gegenüber angegeben. In diesem Fall ist das die Entfernung zwischen dem Urheber des Datasets und den Frauen, die ihm als potenzielle Matches angezeigt werden. Berechnet wird immer die Entfernung zwischen den Stand- und nicht den Wohnorten, da so der tatsächliche Aufenthaltsort beider Personen angegeben wird. Ausgewiesen wird der Abstand in Kilometern.
#
# - isFlirtstar:
#
# - isHighlighted: Mit der Highlight Funktion auf LOVOO ist es den Usern möglich, das eigene Profil gegenüber anderen hervorzuheben. Das Profil wird dann über den Zeitraum des Highlights bei potenziellen Partnern in der Umgebung verstärkt angezeigt und erhöht damit die Möglichkeit, von anderen gesehen zu werden und damit das perfekte Match zu bekommen.
#
# - isInfluencer:
# - isMobile:
#
# - isNew: Dieses Merkmal wird gesetzt, wenn der User die Plattform erst für kurze Zeit nutzt.
#
# - isOnline: Nutzer gerade auf der Plattform aktiv sind, wird das auf ihrem Profil angezeigt, sie sind dann in diesem Moment online. Hierdurch bekommen mögliche Matches einen Hinweis darauf, ob sie beispielsweise mit einer schnellen Antwort rechnen können oder eine Interessensbekundung im derzeit wahrgenommen wird.
#
# - isVip: LOVOO bietet auf seiner Plattform eine VIP Mitgliedschaft an, die dem Nutzer Vorteile und weitere Funktionen gegenüber Nutzern verschafft, die die kostenlose Funktion nutzen. Hierzu zählen beispielsweise unbegrenzte Chats, eine Übersicht über alle Profilbesucher oder ein Invisible Mode, der eine anonyme Nutzung ermöglicht.
#
# - lang_count: Da LOVOO international tätig ist, sprechen verschiedene Nutzer unterschiedliche Sprachen. Wie viele Sprachen der Profilinhaber insgesamt spricht, wird dabei in der Spalte "lang_count" gezählt. Gesondert ausgewiesen werden im Data Set die Sprachen Französisch, Englisch, Deutsch, Italienisch, Spanisch und Portugiesisch. Diese Auswahl begründet sich in den Kernmärkten von LOVOO, die in Deutschland, Österreich, Schweiz, Großbritannien, Frankreich, Spanien, Italien und Brasilien liegen.
#
# - lang_fr: Mit "true" oder "flase" wird hier im Data Set angegeben, ob der Nutzer Französisch spricht.
# - lang_en: Mit "true" oder "flase" wird hier im Data Set angegeben, ob der Nutzer Englisch spricht.
# - lang_de: Mit "true" oder "flase" wird hier im Data Set angegeben, ob der Nutzer Deutsch spricht.
# - lang_it: Mit "true" oder "flase" wird hier im Data Set angegeben, ob der Nutzer Italienisch spricht.
# - lang_es: Mit "true" oder "flase" wird hier im Data Set angegeben, ob der Nutzer Spanisch spricht.
# - lang_pt: Mit "true" oder "flase" wird hier im Data Set angegeben, ob der Nutzer Portugiesisch spricht.
#
# - verified: Als verifiziert gilt ein Account dann, wenn bestätigt geprüft wurde, ob er authentisch ist und tatsächlich eine reale Person repräsentiert. Dies findet in sozialen Netzwerken häufig über ein Abgleich der hochgeladenen Bilder mit einem neu aufgenommenen Foto während des Verifizierungsprozesses statt. Ein als verfiziert gekennzeichneter Account signalisiert dem Gegenüber, dass es sich hier nicht um ein Fakeprofil handelt und eine Interaktion somit sicher möglich ist.
#
# - shareProfileEnabled: LOVOO bietet grundsätzlich die Möglichkeit, ein Profil mit Freunden und bekannten zu teilen. Möchte ein User jedoch nicht, dass das eigene Profil an unbekannte Dritte weiterverschickt wird, kann die Sharing Option deaktiviert werden. So wird sichergestellt, dass der Account nur durch andere Nutzer auf der Plattform eingesehen werden kann.
#
# - lastOnlineDate: Diese Variable gibt an, an welchem Tag der User das letzte mal online war, also zuletzt auf der Plattform interagiert hat.
#
# - lastOnlineTime: Ebenso wie die vorherige Spalte gibt diese an, wann die letzte Aktivität auf LOVOO stattgefunden hat. Anders als zuvor wird hier nicht das Datum, sondern die Uhrzeit weggeschrieben.
#
# - birthd:
#
# - crypt:
#
# - freetext: In dieser Spalte wird ein beliebiger Text ausgegeben, den jeder User auf seinem Profil individuell formulieren kann, um beispielsweise entwas über sich zu erzählen, um so z.B. die Identifizierung gemeinsamer Interessen zu ermöglichen.
#
# - whazzup:
#
# - pictureId: Ähnlich wie bei der UserID wird auch bei hochgeladenen Bildern eine eindeutige Identifizierungsnummer mitgegeben, die sich einzig auf dieses bestimmte Bild bezieht. In diesem Data Set soll die Picture ID dabei helfen, das Bild eines Profils aufrufen zu können. Für den Usecase dieses Projekts ist dies jedoch nicht relevant.
#
# - userId: Für jeden angelegten Account wird bei Erstellung im Hintergrund eine UserID hinterlegt. Dabei handelt es sich um eine eindeutig zuordenbar Benutzerkennung, anhand derer das Profil identifiziert werden kann, um ihm beispielsweise bestimmt Rechte und Merkmale zuzuweisen.
#
# - isSystemProfile:
#
#
# #### Datenerhebung
#
# Die Erhebung der Daten für den Datensatz erfolgte im Frühjahr 2015 durch gezielte Erfassung von Nutzerprofilinformationen auf LOVOO. Für diese Zwecke wurden eigens vom Urheber entwickelte Tools eingesetzt, die es ermöglichten, während der Nutzung der Plattform, des Aufrufens von Profilen und Stellens von Suchanfragen präzise Daten zu sammeln.
#
# Um die Datenerhebung durchzuführen, wurden zwei Profile erstellt, die den Empfehlungen des Lovoo-Algorithmus folgten. Diese Profile waren auf die Person und die Interessen des Urhebers ausgerichtet und signalisierten Offenheit für Freundschaften, Chats und Dates. Da der Urheber männlich ist und ausschließlich auf der Suche nach Frauen ist, sind diese Faktoren bei Erstellung der Profile und der Auswahl potenzieller Matches durch den Algorithmus eingeflossen. Folglich besteht der Datensatz ausschließlich aus weiblichen Nutzerprofilen. Um auch Daten für andere Geschlechter oder Altersgruppen zu erfassen, müsste eine separate Datenerhebung mit entsprechenden Profilen erfolgen.
#
# Interessanterweise zeigte sich, dass der Empfehlungsalgorithmus von Lovoo häufig dieselben Nutzerprofile ausgab. Dies lässt darauf schließen, dass der Algorithmus wahrscheinlich stark auf Einstellungen wie den Standort angewiesen war, um Nutzer in der Nähe zu empfehlen. Möglicherweise spielten auch Cookies eine Rolle. Diese Faktoren führten dazu, dass die Anzahl der unterschiedlichen Nutzerprofile, die in den Datensatz aufgenommen wurden, begrenzt war.

# %% [markdown]
# ## Analysis approach
#
# In this section, you will provide a brief overview of your analysis approach. This includes:
#
# -   Description of the response variable.
# -   Visualization and summary statistics for the response variable.
# -   List of variables that will be considered as predictors
# -   Your model type (what kind of model(s) will you use ... e.g. linear regression)

# %% [markdown]
# ## Data dictionary
#
# *Create a data dictionary for all the variables in your data set. You may fill out the data description table or create your own table with Pandas:*
#
# <br>
#
#
# | Name  |   Description	| Role   	| Type   	|  Format 	|
# |---	|---	        |---    	|---	    |---	|
# |   	|   	        |   	    |   	    |   	|
# |   	|   	        |   	    |   	    |   	|
# |   	|   	        |   	    |   	    |   	|
#
#
# <br>
#
# - `Role`: response, predictor, ID (ID columns are not used in a model but can help to better understand the data)
#
# - `Type`: nominal, ordinal or numeric
#
# - `Format`: int, float, string, category, date or object

# %%
import pandas as pd

data = {
    'Name': ['gender','genderLooking', 'age', 'name','counts_details','counts_pictures','counts_profileVisits','counts_kisses','counts_fans','counts_g', 'flirtInterests_chat','flirtInterests_friends','flirtInterests_date','country','city','location','distance'],
    'Description': ['Geschlecht des Profilinhabers z.B. männlich, weiblich', 'Geschlecht der gesuchten Kontakte', 'Alter des Profilinhabers', 'Nutzername des Profilinhabers','Anzahl der Angaben auf dem Account','Anzahl der hochgeladenen Bilder','Anzahl der Besuche anderer User auf dem eigenen Profil','Anzahl erhaltener Kisses, also Aufmerksamkeitsbekundungen','Anzahl an Fans des eigenen Profils etwa wie Follower','Anzahl','Angabe, ob der Profilinhaber an Chats interessiert ist','Angabe, ob der Profilinhaber nach Freundschaften sucht','Angabe, ob der Profilinhaber nach Dates sucht','Herkunftsland des Profilinhabers','Wohnort des Profilinhabers','Aktueller Aufenthaltsort des Profilinhabers','Entfernung zum potenziellen Match'],
    'Role': ['predictor','predictor', 'predictor', 'ID','predictor','predictor','response','response','response','tbd','predictor','predictor','predictor','predictor','predictor','predictor','predictor'],
    'Type': ['nominal','nominal', 'numerisch','nominal','numerisch','numerisch','numerisch','numerisch','numerisch','numerisch','nominal','nominal','nominal','nominal','nominal','nominal','numerisch'],
    'Format': ['object', 'object', 'float', 'object','float','float','float','float','float','float','object','object','object','object','object','object','float']
}

data_dictionary = pd.DataFrame(data)

data_dictionary
# Out:
#                       Name                                        Description  \
# 0                   gender  Geschlecht des Profilinhabers z.B. männlich, w...
# 1            genderLooking                  Geschlecht der gesuchten Kontakte
# 2                      age                           Alter des Profilinhabers
# 3                     name                      Nutzername des Profilinhabers
# 4           counts_details                 Anzahl der Angaben auf dem Account
# 5          counts_pictures                    Anzahl der hochgeladenen Bilder
# 6     counts_profileVisits  Anzahl der Besuche anderer User auf dem eigene...
# 7            counts_kisses  Anzahl erhaltener Kisses, also Aufmerksamkeits...
# 8              counts_fans  Anzahl an Fans des eigenen Profils etwa wie Fo...
# 9                 counts_g                                             Anzahl
# 10     flirtInterests_chat  Angabe, ob der Profilinhaber an Chats interess...
# ...

# %%
new_data = {
    'Name': ['isFlirtstar','isHighlighted','isInfluencer','isMobile','isNew','isOnline','isVip','lang_count','lang_fr','lang_en','lang_de','lang_it','lang_es','lang_pt','verified','shareProfileEnabled','lastOnlineDate','lastOnlineTime','birthd','crypt','freetext','whazzup','pictureId','userId','isSystemProfile'],
    'Description': ['tbd','Hervorgehobenes Profil durch Highlightfuntkion','tbd','tbd','Neuer Account auf der Plattform','User ist derzeit auf der Plattform aktiv','User hat Bezahlversion von LOVOO','Anzahl der Sprachen, die der User beherrscht.','Angabe, ob User Französisch spricht.','Angabe, ob User Englisch spricht.','Angabe, ob User Deutsch spricht.','Angabe, ob User Italienisch spricht.','Angabe, ob User Spanisch spricht.','Angabe, ob User Portugiesisch spricht.','Angabe, ob die Autentizität des Profils geprüft wurde','Die Teilen Funktion des Profils wurde deaktiviert','Timestamp der letzten Aktivität','Zeit der letzten Aktivität','tbd','tbd','Kurzbeschreibung auf dem Profil','tbd','Identifikationsnummer einzelner Bilder','Identifikationsnummer des Users','tbd'],
    'Role': ['predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','predictor','ID','ID','ID','ID','ID','ID','ID','ID','ID'],
    'Type': ['nominal','nominal','nominal','nominal','nominal','nominal','nominal','numerisch','nominal','nominal','nominal','nominal','nominal','nominal','nominal','nominal','tbd','tbd','numerisch','tbd','nominal','nominal','nominal','nominal','nominal'],
    'Format': ['float','float','float','float','float','float','float','float','object','object','object','object','object','object','float','float','object','float','float','float','object','object','object','object','float']
}


data_dictionary = pd.concat([data_dictionary, pd.DataFrame(new_data)], ignore_index=True)

# %%
data_dictionary
# Out:
#                       Name                                        Description  \
# 0                   gender  Geschlecht des Profilinhabers z.B. männlich, w...
# 1            genderLooking                  Geschlecht der gesuchten Kontakte
# 2                      age                           Alter des Profilinhabers
# 3                     name                      Nutzername des Profilinhabers
# 4           counts_details                 Anzahl der Angaben auf dem Account
# 5          counts_pictures                    Anzahl der hochgeladenen Bilder
# 6     counts_profileVisits  Anzahl der Besuche anderer User auf dem eigene...
# 7            counts_kisses  Anzahl erhaltener Kisses, also Aufmerksamkeits...
# 8              counts_fans  Anzahl an Fans des eigenen Profils etwa wie Fo...
# 9                 counts_g                                             Anzahl
# 10     flirtInterests_chat  Angabe, ob der Profilinhaber an Chats interess...
# ...
