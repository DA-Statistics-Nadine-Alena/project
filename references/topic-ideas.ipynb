# %% [markdown]
# # Topic ideas
#
# ---
#
# Group name: Gruppe C (Alena und Nadine)
#
# ---

# %% [markdown]
# ## Name of topic idea 1
#
# ### Data source
#
# Den Datensatz unseres Projekts haben wir auf der nachfolgenden Website gefunden und heruntergeladen.
# https://data.world/jfreex/dating-app-user-profiles-stats-lovoo-v3
#
# Im Frühjahr 2015 wurden die Informationen für diesen Datensatz erhoben. Hierzu wurden eigene Accounts erstellt und die Profile angezeigter potentieller Matches gescraped, die ausgelesenen Daten wurden anschließend gespeichert. Da die gesammelten Daten auch realen Vorschlägen für angelegte Profile basiert, enthält der Datensatz vorallem Daten, die den Suchcharakteristika entsprechen. Aufgrund der Einschränkungen enthält die csv-Datei nur Nutzerdaten weiblichen User.
#
#
#
#
# ### Data characterisitcs
#
# Der zugrundeliegende Datensatz beinhaltet Userdaten von LOVOO Nutzern. Bei LOVOO handelt es sich um eine Dating-Plattform, die mithilfe einer App Kontakt zwischen Singles herstellen sollen. Hierbei werden Standortdaten berücksichtigt, um Singles in der Nähe zu finden. Da zunächst kein persönlicher Kontakt hergestellt wird, ist das Userprofil sowie alle dort getätigten Angaben und hochgeladenen Bilder ausschlaggebend für die Präsentation seiner Persönlichkeit. LOVOO gibt es bereits seit 2011.
#
# Der Datensatz enthält Angaben der Nutzer auf ihrem Profil. Neben persönlichen Daten wie Name, Alter oder Aufenthaltsort werden auch datingspezifische Informationen, wie das Geschlecht des gesuchten Partners, angezeigt. Darüber hinaus sind Aktivitätsdaten des Profils Teil des Datensatzes, wie zum Beispiel die Anzahl der Fans oder Kisses. Auch der aktuelle Status des Nutzers wird in den Daten aufgeführt. Diese geben Auskunft über den Erfolg des Profils, also wie häufig die Vorstellungsseite potenzielle Partner dazu veranlasst, Kontakt aufzubauen.
#
#
# ### Research question
#
# Die Nutzer können verschiedene Status erreichen. Auf Basis welcher Daten können wir den Status eines Nutzers vorhersagen? Hierbei könnten das Alter, die Aktivitäten, die Interessen oder auch zum Beispiel die Anzahl der Fotos einwirken.
#
# Die Anzahl der Profilbesuche gibt Auskunft darüber, wie erfolgreich der Nutzer bei der Suche nach einem Match oder sogar zukünftigen Partner ist. Wir möchten genauer untersuchen welchen Einfluss verschiedene Faktoren auf die Anzahl der Profilbesuche haben. Mögliche Einflussgrößen sind beispielweise Interessen, Anzahl der Bilder oder auch das Alter eines Nutzers.
#
#
# ### Overview of data

# %%
import pandas as pd

# %%
URL = 'https://raw.githubusercontent.com/DA-Statistics-Nadine-Alena/project/main/references/Lavoo%20User%20Daten.csv'
df = pd.read_csv(URL)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 URL = 'https://raw.githubusercontent.com/DA-Statistics-Nadine-Alena/project/main/references/Lavoo%20User%20Daten.csv'
# ----> 2 df = pd.read_csv(URL)
#
# ...

# %%
import pandas as pd

df = pd.read_csv('Lavoo User Daten.csv', delimiter=',', engine='python', quoting=3, on_bad_lines='skip')

# DataFrame anzeigen
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <<<<<<< HEAD
# ...
