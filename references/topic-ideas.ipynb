# %% [markdown]
# # Topic ideas
#
# ---
#
# Group name: Gruppe C (Alena und Nadine)
#
# ---

# %% [markdown]
# ## Name of topic idea 1
#
# ### Data source
#
# Den Datensatz unseres Projekts haben wir auf der nachfolgenden Website gefunden und heruntergeladen.
# https://data.world/jfreex/dating-app-user-profiles-stats-lovoo-v3
#
# Im Frühjahr 2015 wurden die Informationen für diesen Datensatz erhoben. Hierzu wurden eigene Accounts erstellt und die Profile angezeigter potentieller Matches gescraped, die ausgelesenen Daten wurden anschließend gespeichert. Da die gesammelten Daten auch realen Vorschlägen für angelegte Profile basiert, enthält der Datensatz vorallem Daten, die den Suchcharakteristika entsprechen. Aufgrund der Einschränkungen enthält die csv-Datei nur Nutzerdaten weiblichen User.
#
#
#
#
# ### Data characterisitcs
#
# Der zugrundeliegende Datensatz beinhaltet Userdaten von LOVOO Nutzern. Bei LOVOO handelt es sich um eine Dating-Plattform, die mithilfe einer App Kontakt zwischen Singles herstellen sollen. Hierbei werden Standortdaten berücksichtigt, um Singles in der Nähe zu finden. Da zunächst kein persönlicher Kontakt hergestellt wird, ist das Userprofil sowie alle dort getätigten Angaben und hochgeladenen Bilder ausschlaggebend für die Präsentation seiner Persönlichkeit. LOVOO gibt es bereits seit 2011.
#
# Der Datensatz enthält Angaben der Nutzer auf ihrem Profil, jede Zeile repräsentiert dabei einen User. Neben persönlichen Daten wie Name, Alter oder Aufenthaltsort werden auch datingspezifische Informationen, wie das Geschlecht des gesuchten Partners, angezeigt. Darüber hinaus sind Aktivitätsdaten des Profils Teil des Datensatzes, wie zum Beispiel die Anzahl der Fans oder Kisses. Auch der aktuelle Status des Nutzers wird in den Daten aufgeführt. Diese geben Auskunft über den Erfolg des Profils, also wie häufig die Vorstellungsseite potenzielle Partner dazu veranlasst, Kontakt aufzubauen.
#
#
# ### Research question
#
# Als User kann man auf der Plattform Fans generieren. Durch Klassifikation möchten wir ermitteln, welche Merkmale ein Profil haben muss, um Fans für sich zu gewinnen. Ziel ist es, für ein beliebiges Profil mit festgelegten Merkmalen vorhersagen zu können, ob es Fans generieren wird oder nicht.
#
# Die Anzahl der Profilbesuche gibt Auskunft darüber, wie erfolgreich der Nutzer bei der Suche nach einem Match oder sogar zukünftigen Partner potenziell ist. Wir möchten genauer untersuchen welchen Einfluss verschiedene Faktoren auf die Anzahl der Profilbesuche haben. Mögliche Einflussgrößen sind beispielweise Anzahl der Bilder oder auch das Alter eines Nutzers.
#
#
# ### Overview of data

# %%
import pandas as pd

# %%
URL = 'https://raw.githubusercontent.com/DA-Statistics-Nadine-Alena/project/main/references/LOVOO_Daten.csv'
df = pd.read_csv(URL)

# %%
df.head()
# Out:
#   gender genderLooking   age          name  counts_details  counts_pictures  \
# 0      F             M  25.0         daeni            1.00              4.0
# 1      F             M  22.0   italiana 92            0.85              5.0
# 2      F             M  21.0       Lauraaa            0.00              4.0
# 3      F          none  20.0    Qqkwmdowlo            0.12              3.0
# 4      F             M  21.0  schaessie {3            0.15             12.0
#
#    counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# 0                8279.0          239.0          0.0       3.0  ...
# 1                 663.0           13.0          0.0       0.0  ...
# 2                1369.0           88.0          0.0       2.0  ...
# 3               22187.0         1015.0          2.0       3.0  ...
# 4               35262.0         1413.0          9.0      12.0  ...
#
#   shareProfileEnabled        lastOnlineDate lastOnlineTime birthd crypt  \
# 0                 1.0  2015-04-25T20:43:26Z   1.429995e+09    0.0   NaN
# 1                 1.0  2015-04-26T09:19:35Z   1.430040e+09    0.0   NaN
# 2                 1.0  2015-04-06T14:24:07Z   1.428330e+09    0.0   NaN
# 3                 1.0  2015-04-07T11:21:01Z   1.428406e+09    0.0   NaN
# 4                 1.0  2015-04-06T14:25:20Z   1.428330e+09    0.0   NaN
#
#                                  freetext  \
# 0  Nur tote Fisch schwimmen mit dem Strom
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                                     whazzup                 pictureId  \
# 0   Nur tote fische schwimmen mit dem strom  4e3842f79b70e7ea57000064
# 1                             Primaveraaa<3  4e3d34bf5d2bce7b160006a3
# 2                                       NaN  4ec96c090dc82cb25d00000a
# 3  Je pense donc je suis.  Instagram quedev  4eef8b81ebf2c8f64000000c
# 4                     Instagram: JESSSIESCH  4ef3cc5aa9d0b3d07d000017
#
#                      userId  isSystemProfile
# 0  55303fc3160ba0eb728b4575              NaN
# 1  552e7b61c66da10d1e8b4c82              NaN
# 2  54a584ecc56da128638b4674              NaN
# 3  54c92738076ea1b5338b4735              NaN
# 4  54e1a6f6c76da135748b4a3a              NaN
#
# [5 rows x 42 columns]

# %%
df.tail()
# Out:
#      gender genderLooking   age    name  counts_details  counts_pictures  \
# 3850      F             M  21.0    B**f            0.85              1.0
# 3851      F             M  20.0   Ma**e            1.00              8.0
# 3852      F             M  20.0   Ma**e            1.00              8.0
# 3853      F             M  23.0  Eni**n            0.96              8.0
# 3854      F             M  23.0  Eni**n            0.96              9.0
#
#       counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# 3850                 280.0           15.0          0.0       0.0  ...
# 3851                1014.0           43.0          3.0       0.0  ...
# 3852                1101.0           46.0          3.0       0.0  ...
# 3853                8702.0          142.0          0.0       0.0  ...
# 3854                8904.0          143.0          0.0       0.0  ...
#
#      shareProfileEnabled        lastOnlineDate lastOnlineTime birthd crypt  \
# 3850                 1.0  2015-04-07T00:08:59Z   1.428365e+09    0.0   1.0
# 3851                 1.0  2015-04-06T07:54:34Z   1.428307e+09    0.0   1.0
# 3852                 1.0  2015-04-06T07:54:34Z   1.428307e+09    0.0   1.0
# 3853                 0.0  2015-04-06T15:47:15Z   1.428335e+09    0.0   1.0
# 3854                 0.0  2015-04-19T08:38:08Z   1.429433e+09    0.0   1.0
#
#      freetext                                            whazzup  \
# 3850      NaN                                                NaN
# 3851      NaN  Marie ॐ                            🎉Goa.      ...
# 3852      NaN  Marie ॐ                            🎉Goa.      ...
# 3853      NaN                           ruhig shriebe😉. bissä ni
# 3854      NaN                           ruhig shriebe😉. bissä ni
#
#                                               pictureId  \
# 3850  CRYqKLbQ1+pd5CVSmGGccV+EggT4oGRmaXWhnn5jhMg9Jz...
# 3851  CRYq7MGpxHpEKfWhmwJygGmRNadHkC9XxPjktwvaiLm6Te...
# 3852  CRYVOrW7zgSV+NPGili4nZeREmQ0rAAXCZunTXp9KRLat1...
# 3853  CRYsH4q+r4fCkC8+leJqDdJQtbUNQGCyqLx36aDsEzC5b9...
# 3854  CRYbrX0C8ToNrsDqLPf+kLsCSuDY0TOhyKSo3Phw98sbl+...
#
#                                 userId  isSystemProfile
# 3850  cb958a9459216acd4dd06f213fe63685              NaN
# 3851  d5a7edbcb59fcb092871bdcde7f142ca              NaN
# 3852  d5a7edbcb59fcb092871bdcde7f142ca              NaN
# 3853  e532a6060fe4e5902c66086d905a9d53              NaN
# 3854  dc186f3855343c9f096c484f6d363aac              NaN
#
# [5 rows x 42 columns]

# %%
df.describe().T
# Out:
#                        count          mean            std           min  \
# age                   3428.0  2.199592e+01       1.966598  1.800000e+01
# counts_details        3426.0  5.539872e-01       0.328922  0.000000e+00
# counts_pictures       3426.0  4.610917e+00       4.363296  0.000000e+00
# counts_profileVisits  3426.0  3.515930e+03    6171.558587  0.000000e+00
# counts_kisses         3426.0  1.479197e+02     342.786456  0.000000e+00
# counts_fans           3426.0  2.256859e+00      11.659049  0.000000e+00
# counts_g              3426.0  1.179218e-01       1.131675  0.000000e+00
# distance              3406.0  2.030722e+02     144.682194  0.000000e+00
# isFlirtstar           3426.0  1.138354e-02       0.106100  0.000000e+00
# isHighlighted         3426.0  1.138354e-02       0.106100  0.000000e+00
# isInfluencer          3426.0  0.000000e+00       0.000000  0.000000e+00
# isMobile              3426.0  7.410975e-01       0.438096  0.000000e+00
# isNew                 3426.0  2.524810e-01       0.434499  0.000000e+00
# isOnline              3426.0  5.951547e-01       0.490934  0.000000e+00
# isVip                 3426.0  1.984822e-02       0.139499  0.000000e+00
# lang_count            3426.0  1.103036e+00       0.569961  0.000000e+00
# verified              3426.0  2.043199e-01       0.403263  0.000000e+00
# shareProfileEnabled   3426.0  9.640981e-01       0.186073  0.000000e+00
# lastOnlineTime        3425.0  1.428903e+09  821476.482464  1.426592e+09
# birthd                3426.0  4.378284e-03       0.066033  0.000000e+00
# crypt                   20.0  1.000000e+00       0.000000  1.000000e+00
# isSystemProfile          2.0  1.000000e+00       0.000000  1.000000e+00
#
#                                25%           50%           75%           max
# age                   2.000000e+01  2.200000e+01  2.400000e+01  2.800000e+01
# counts_details        3.100000e-01  6.200000e-01  8.500000e-01  1.000000e+00
# counts_pictures       2.000000e+00  3.000000e+00  6.000000e+00  3.000000e+01
# counts_profileVisits  3.622500e+02  1.151500e+03  3.895750e+03  5.894400e+04
# counts_kisses         1.000000e+01  4.200000e+01  1.340000e+02  6.155000e+03
# counts_fans           0.000000e+00  0.000000e+00  0.000000e+00  2.410000e+02
# counts_g              0.000000e+00  0.000000e+00  0.000000e+00  4.300000e+01
# distance              8.130000e+01  1.720000e+02  3.177500e+02  1.632000e+03
# isFlirtstar           0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# isHighlighted         0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# isInfluencer          0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# isMobile              0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# isNew                 0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# isOnline              0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# isVip                 0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# lang_count            1.000000e+00  1.000000e+00  1.000000e+00  9.000000e+00
# verified              0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# shareProfileEnabled   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# lastOnlineTime        1.428332e+09  1.428387e+09  1.429985e+09  1.430647e+09
# birthd                0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# crypt                 1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# isSystemProfile       1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3855 entries, 0 to 3854
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gender                  3855 non-null   object
#  1   genderLooking           3428 non-null   object
#  2   age                     3428 non-null   float64
#  3   name                    3428 non-null   object
#  4   counts_details          3426 non-null   float64
#  5   counts_pictures         3426 non-null   float64
#  6   counts_profileVisits    3426 non-null   float64
#  7   counts_kisses           3426 non-null   float64
#  8   counts_fans             3426 non-null   float64
#  9   counts_g                3426 non-null   float64
#  10  flirtInterests_chat     3426 non-null   object
#  11  flirtInterests_friends  3426 non-null   object
#  12  flirtInterests_date     3426 non-null   object
#  13  country                 3426 non-null   object
#  14  city                    3158 non-null   object
#  15  location                3418 non-null   object
#  16  distance                3406 non-null   float64
#  17  isFlirtstar             3426 non-null   float64
#  18  isHighlighted           3426 non-null   float64
#  19  isInfluencer            3426 non-null   float64
#  20  isMobile                3426 non-null   float64
#  21  isNew                   3426 non-null   float64
#  22  isOnline                3426 non-null   float64
#  23  isVip                   3426 non-null   float64
#  24  lang_count              3426 non-null   float64
#  25  lang_fr                 3426 non-null   object
#  26  lang_en                 3426 non-null   object
#  27  lang_de                 3426 non-null   object
#  28  lang_it                 3426 non-null   object
#  29  lang_es                 3426 non-null   object
#  30  lang_pt                 3426 non-null   object
#  31  verified                3426 non-null   float64
#  32  shareProfileEnabled     3426 non-null   float64
#  33  lastOnlineDate          3425 non-null   object
#  34  lastOnlineTime          3425 non-null   float64
#  35  birthd                  3426 non-null   float64
#  36  crypt                   20 non-null     float64
#  37  freetext                69 non-null     object
#  38  whazzup                 1848 non-null   object
#  39  pictureId               3411 non-null   object
#  40  userId                  3335 non-null   object
#  41  isSystemProfile         2 non-null      float64
# dtypes: float64(22), object(20)
# memory usage: 1.2+ MB
